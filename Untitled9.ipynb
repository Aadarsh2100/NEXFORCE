# %%
import numpy as np
import pandas as pd

# %%
doc = pd.read_csv("SOCR-HeightWeight.csv")

# %%
doc
# Out:
#        Index  Height(Inches)  Weight(Pounds)
# 0          1        65.78331        112.9925
# 1          2        71.51521        136.4873
# 2          3        69.39874        153.0269
# 3          4        68.21660        142.3354
# 4          5        67.78781        144.2971
# ...      ...             ...             ...
# 24995  24996        69.50215        118.0312
# 24996  24997        64.54826        120.1932
# 24997  24998        64.69855        118.2655
# 24998  24999        67.52918        132.2682
# 24999  25000        68.87761        124.8742
#
# [25000 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# doc['Index'].plot(kind='hist', bins=20, title='Index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
print(np.mean(doc["Height(Inches)"]))
print(np.mean(doc["Weight(Pounds)"]))
# Out:
# 67.99311359679999
# 127.07942116080001

# %%
print(np.median(doc["Weight(Pounds)"]))
print(np.median(doc["Height(Inches)"]))
# Out:
# 127.15775
# 67.9957

# %%
from scipy import stats as st
print(st.mode((doc["Weight(Pounds)"])))
print(st.mode((doc["Height(Inches)"])))
# Out:
# ModeResult(mode=124.7975, count=4)
# ModeResult(mode=65.65796, count=3)
